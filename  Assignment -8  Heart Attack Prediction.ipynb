# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("heart.csv")

# %%
data.head(10)
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
# 5   57    1   0     140   192    0        1       148     0      0.4    1
# 6   56    0   1     140   294    0        0       153     0      1.3    1
# 7   44    1   1     120   263    0        1       173     0      0.0    2
# 8   52    1   2     172   199    1        1       162     0      0.5    2
# 9   57    1   2     150   168    0        1       174     0      1.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
data.shape
# Out:
# (303, 14)

# %%
data.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
# Since the data doesnot contain any null values..
# Thers no need to clean datasets..

# %% [markdown]
# ## Distribution Of Gender With respect to Heart Attack

# %%
sns.countplot(x = 'sex' , hue = 'output' ,  data = data)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
plt.figure(figsize=(8,6))
data['output'].value_counts().plot(kind='bar')
plt.xlabel("People Suffered From Heart Attack Or Not ")
plt.ylabel("Number Of People ")
plt.title("Count of Number of people Got Heart Attack")
# Out:
# Text(0.5, 1.0, 'Count of Number of people Got Heart Attack')

# %%
ratio = data["output"].value_counts()/len(data["output"])*100
ratio
# Out:
# 1    54.455446
# 0    45.544554
# Name: output, dtype: float64

# %% [markdown]
# # It shows that around 54% people got heart attack

# %% [markdown]
# ### Lets Look at the age group

# %%
plt.figure(figsize=(20,20))
sns.countplot(x="age",data=data)
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
sns.distplot(data['age'], color='red')
plt.title('Distribution of Ages', fontsize=15, pad = 10)
plt.xlabel('Ages', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.show()
# Out:
# c:\python\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize =(20,8))
sns.countplot(x = data['age'],hue=data['output'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
#  Most of the people are in the age group of 50-60
# Hence old age person are likely to get heart attack

# %%
print(data["age"].max())
# Out:
# 77

# %%
data.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %% [markdown]
# ### Lets Compare male and female Patients

# %%
sex_data = data.sex.map({1: 'Male', 0: 'Female'})
sns.countplot(sex_data, hue = 'output',data = data)
# Out:
# c:\python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# Clearly Mostly  Females Are  More Heart Attack Patients

# %% [markdown]
# ###  Lets Check on the basis Of Blood pressure

# %%
sns.set(rc = {'axes.facecolor': 'black', 'axes.grid': False,})
plt.figure(figsize = [10,6])

sns.distplot(data['trtbps'], color='magenta')
plt.title('Distribution of Blood Pressure among patients', fontsize=15, pad = 10)
plt.xlabel('Blood Pressure', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.show()
# Out:
# c:\python\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### On The basis Of  Cholestrol

# %%
plt.figure(figsize = [10,6])

sns.distplot(data['chol'], color='cyan')
plt.title('Distribution of Cholestrol among patients', fontsize=15, pad = 10)
plt.xlabel('Cholestrol', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.show()
# Out:
# c:\python\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set(rc = {'axes.facecolor': 'white', 'axes.grid': False,})
for i, predictor in enumerate(data.drop(columns=['output','age','trtbps','chol','thalachh','oldpeak'])):
    plt.figure(i)
    sns.countplot(data=data, x=predictor, hue='output')

# %%
sns.lmplot(x="thalachh",y="oldpeak",data=data)
plt.show()

# %%
plt.hist(x="thalachh",data=data)
# Out:
# (array([ 1.,  6., 11., 26., 35., 53., 77., 63., 26.,  5.]),
#  array([ 71. ,  84.1,  97.2, 110.3, 123.4, 136.5, 149.6, 162.7, 175.8,
#         188.9, 202. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.kdeplot(data=data, x="oldpeak", hue="output")
# Out:
# <AxesSubplot:xlabel='oldpeak', ylabel='Density'>

# %% [markdown]
# Clearly  Heartattack number is high when old peak is at starting phase

# %% [markdown]
# ### Lets See How Blood Pressure is related to Age , Cholestrol and Heartrate

# %%
sns.lineplot(y='trtbps',x='age',data=data)
plt.title('blood pressure with age')
plt.xlabel('age')
plt.ylabel('blood pressure')
plt.show()

# %%
sns.lineplot(y='chol',x='age',data=data)
plt.title('cholestrol level with age')
plt.xlabel('age')
plt.ylabel('cholestrol level')
plt.show()

# %%
sns.lineplot(y='thalachh',x='age',data=data)
plt.title('heart rate with age')
plt.xlabel('age')
plt.ylabel('heart rate')
plt.show()

# %%
# plots for Continuous features to see any significant correlation among the features.

# %%
pair = data[['age', 'trtbps', 'chol', 'thalachh', 'oldpeak', 'output']]


ax = sns.pairplot(pair, hue='output', palette='rocket')
ax._legend.remove()
ax.fig.legend(title='Output', labels = ['Heart Attack', 'No Heart Attack'])
ax.fig.subplots_adjust(right=0.8, top=1)

plt.show()

# %%
data.hist(figsize=(20,10))
plt.show()
# Out:
# c:\python\lib\site-packages\pandas\plotting\_matplotlib\tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():

# %%
data.corr()
# Out:
#                age       sex        cp    trtbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trtbps    0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalachh -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exng      0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slp      -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# caa       0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thall     0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
data.corr()["output"].sort_values(ascending=False)
# Out:
# output      1.000000
# cp          0.433798
# thalachh    0.421741
# slp         0.345877
# restecg     0.137230
# fbs        -0.028046
# chol       -0.085239
# trtbps     -0.144931
# age        -0.225439
# sex        -0.280937
# thall      -0.344029
# caa        -0.391724
# oldpeak    -0.430696
# exng       -0.436757
# Name: output, dtype: float64

# %%
data.corr()["output"].sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %% [raw]
# Inights
# 1. Heart Attack Patients are high in  case of features like cp, thalach,caa, slp
# 2.  Age also plays a vital role maximum person nfrom age group of 45-60are suffering from heart attack
# 3.Mostly males are suffering from heart attack.

# %%
# Lets Check the test data 
test_data = pd.read_csv('o2Saturation.csv')

# %%
test_data.head()
# Out:
#    98.6
# 0  98.6
# 1  98.6
# 2  98.6
# 3  98.1
# 4  97.5

# %%
X_train = data.drop(['output'],axis =1).values
Y_train =data['output'].values

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(X_train, Y_train, test_size = 0.20)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train , y_train)
# Out:
# c:\python\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.8032786885245902
